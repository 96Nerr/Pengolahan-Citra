# %% [markdown]
# <a href="https://colab.research.google.com/github/96Nerr/Pengolahan-Citra/blob/main/meet-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#connect drive
from google.colab import drive
drive.mount('/content/drive')
image_path = ('/content/drive/MyDrive/Pengolahan Citra/bahan_citra/yuji_itadori.jpg')
# Out:
# Mounted at /content/drive

# %%
image = cv2.imread(image_path)

# %%
print(image.shape)
# Out:
# (1080, 1920, 3)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(image)
plt.title('yuji')
plt.axis('off')
plt.show()

# %%
image_rgb=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(5, 5))
plt.imshow(image_rgb)
plt.title('yuji')
plt.axis('off')
plt.show()

# %%
image_rgb=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(5, 5))
plt.imshow(image_rgb)
plt.title('yuji')
plt.axis('off')
plt.show()

# %%
#Menampilkan dua gambar dalam satu jendela
axes[0]= (image)

fig, axis = plt.subplots(1, 2, figsize=(20, 5))
axes[0].imshow(gray_image, cmap='gray')
axes[0].set_title("gambar grayscael")
axes[0].axis('off')

axes[1].imshow(binary_image, cmap='gray')
axes[1].set_title("gambar biner")
axes[1].axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1489714900.py in <cell line: 0>()
#       1 #Menampilkan dua gambar dalam satu jendela
# ----> 2 axes[0]= (image)
#       3
#       4 fig, axis = plt.subplots(1, 2, figsize=(20, 5))
#       5 axes[0].imshow(gray_image, cmap='gray')
#
# NameError: name 'image' is not defined

# %%
#Konversi ke citra negatif
negative_image = 255 - gray_image
plt.figure(figsize=(5, 5))
plt.imshow(negative_image, cmap='gray')
plt.title('gambar negatif')
plt.axis('off')
plt.show

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
