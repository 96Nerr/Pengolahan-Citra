# %% [markdown]
# <a href="https://colab.research.google.com/github/96Nerr/Pengolahan-Citra/blob/main/meet-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#connect drive
from google.colab import drive
drive.mount('/content/drive')
image_path = ('/content/drive/MyDrive/Pengolahan Citra/bahan_citra/Salinan lena256.tif')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
